# %% [markdown]
# ### Reading data

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
from getting_data.import_data import read_data

# %%
data = read_data()

# %% [markdown]
# ### Studying correlation

# %%
from plotting.basic_plotting import plot_correlation

# %%
corr = plot_correlation(
    data
)
corr.to_excel('data/corr.xlsx')
corr
# Out:
# <style type="text/css">
# #T_2a3ec th {
#   font-size: 4pt;
# }
# #T_2a3ec td {
#   padding: 0em 0em;
# }
# #T_2a3ec th:hover {
#   font-size: 12pt;
# }
# #T_2a3ec tr:hover td:hover {
#   max-width: 200px;
#   font-size: 12pt;
# }
# ...

# %% [markdown]
# ### Basic Plot

# %%
from plotting.basic_plotting import basic_plot

# %%
xs = [
    'Empty_Weight',
    'Number_of_passengers',
    'Number_of_passengers',
    'Wing_sweep (°)',
    'Baggage_compartment_volume (m3)',
    'Takeoff_distance (m)',
    'Total_maximum_thrust (kN)',
    'Wing_area (m2)',
    'Baggage_compartment_volume (m3)'
]

ys = [
    'MTOW (kg)',
    'MTOW (kg)',
    'Fuselage_length (m)',
    'Cruise_Mach',
    'MTOW (kg)',
    'MTOW (kg)',
    'MTOW (kg)',
    'MTOW (kg)',
    'Number_of_passengers'
]

degs = [
    1,
    1,
    1,
    1,
    1,
    2,
    1,
    1,
    1,
]

# %%
for x_name,y_name,deg, i in zip(xs,ys,degs, range(1,10)):
    # print(x_name,y_name,deg)
    basic_plot(data,x_name,[y_name], deg)
    print(f'{i} {x_name} vs {y_name}')
# Out:
# 1 Empty_Weight vs MTOW (kg)
# 2 Number_of_passengers vs MTOW (kg)
# 3 Number_of_passengers vs Fuselage_length (m)
# 4 Wing_sweep (°) vs Cruise_Mach
# 5 Baggage_compartment_volume (m3) vs MTOW (kg)
# 6 Takeoff_distance (m) vs MTOW (kg)
# 7 Total_maximum_thrust (kN) vs MTOW (kg)
# 8 Wing_area (m2) vs MTOW (kg)
# 9 Baggage_compartment_volume (m3) vs Number_of_passengers
